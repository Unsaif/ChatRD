# %%
from pathlib import Path
import pandas as pd 
import ast

base_path = Path().resolve() / 'files'

prompts_df = pd.read_excel(base_path / 'prompts_omim_pmid_updated_file_final1.xlsx', index_col='File Name')

prompts_df = prompts_df.dropna()
prompts_df['OMIM'] = prompts_df['OMIM'].astype(int)

# --- if the column is already a real list you can skip this helper ----
def ensure_list(x):
    """Turn stringified list / set into a real Python list."""
    if isinstance(x, list):
        return x
    if isinstance(x, str):
        x = x.strip()
        if not x:
            return []
        try:                                     # try "[...]"  or "{...}"
            obj = ast.literal_eval(x)
            if isinstance(obj, (list, set, tuple)):
                return list(obj)
        except Exception:
            pass
        # fall-back: split on commas
        return [y.strip() for y in x.split(",") if y.strip()]
    return []

preds = pd.read_csv('all_predictions_with_hpo_prompts.csv')
preds["patient_hpo_names"] = preds["patient_hpo_names"].apply(ensure_list)
preds = preds[preds["patient_hpo_names"].apply(len) > 2].copy()

prompts_df = prompts_df.loc[preds['file_name'].unique()]
prompts_df
# Out:
#                                                                        Case Description  \
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  The proband was a female. Disease onset was no...
# PMID_10571775_YAT_II_1_en-prompt.txt  The proband was a male. Disease onset was not ...
# PMID_10580070_A_III_11_en-prompt.txt  The proband was a female. Disease onset occurr...
# PMID_10580070_A_III_13_en-prompt.txt  The proband was a male. Disease onset occurred...
# PMID_10580070_A_III_5_en-prompt.txt   The proband was a female. Disease onset occurr...
# ...                                                                                 ...
# STX_Syrbe_3_en-prompt.txt             The proband was a 5-year, 0-month old child. D...
# STX_Syrbe_4_en-prompt.txt             The proband was a 6-year, 0-month old child. D...
# STX_Syrbe_5_en-prompt.txt             The proband was a 4-year, 0-month old child. D...
# STX_Syrbe_6_en-prompt.txt             The proband was a 2-year, 0-month old child. D...
# STX_Syrbe_8_en-prompt.txt             The proband was a 4-year, 0-month old child. D...
#
#                                                                       Correct Diagnosis  \
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  Distal renal tubular acidosis 4 with hemolytic...
# PMID_10571775_YAT_II_1_en-prompt.txt  Distal renal tubular acidosis 4 with hemolytic...
# PMID_10580070_A_III_11_en-prompt.txt                         Cardiomyopathy dilated 1A
# PMID_10580070_A_III_13_en-prompt.txt                         Cardiomyopathy dilated 1A
# PMID_10580070_A_III_5_en-prompt.txt                          Cardiomyopathy dilated 1A
# ...                                                                                 ...
# STX_Syrbe_3_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_4_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_5_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_6_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_8_en-prompt.txt                 Developmental and epileptic encephalopathy 4
#
#                                         OMIM  \
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  611590
# PMID_10571775_YAT_II_1_en-prompt.txt  611590
# PMID_10580070_A_III_11_en-prompt.txt  115200
# PMID_10580070_A_III_13_en-prompt.txt  115200
# PMID_10580070_A_III_5_en-prompt.txt   115200
# ...                                      ...
# STX_Syrbe_3_en-prompt.txt             612164
# STX_Syrbe_4_en-prompt.txt             612164
# STX_Syrbe_5_en-prompt.txt             612164
# STX_Syrbe_6_en-prompt.txt             612164
# STX_Syrbe_8_en-prompt.txt             612164
#
#                                                                       PMID
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  PMID_10571775_KSN_II_1_en-prompt.txt
# PMID_10571775_YAT_II_1_en-prompt.txt  PMID_10571775_YAT_II_1_en-prompt.txt
# PMID_10580070_A_III_11_en-prompt.txt  PMID_10580070_A_III_11_en-prompt.txt
# PMID_10580070_A_III_13_en-prompt.txt  PMID_10580070_A_III_13_en-prompt.txt
# PMID_10580070_A_III_5_en-prompt.txt    PMID_10580070_A_III_5_en-prompt.txt
# ...                                                                    ...
# STX_Syrbe_3_en-prompt.txt                        STX_Syrbe_3_en-prompt.txt
# STX_Syrbe_4_en-prompt.txt                        STX_Syrbe_4_en-prompt.txt
# STX_Syrbe_5_en-prompt.txt                        STX_Syrbe_5_en-prompt.txt
# STX_Syrbe_6_en-prompt.txt                        STX_Syrbe_6_en-prompt.txt
# STX_Syrbe_8_en-prompt.txt                        STX_Syrbe_8_en-prompt.txt
#
# [4419 rows x 4 columns]

# %%
known_imds = pd.read_csv(base_path / "reconws_diseases.csv")
known_imds
# Out:
#         id diseaseAbbr                                      diseaseName  \
# 0        1       GCH1A                  GTP cyclohydrolase 1 deficiency
# 1        2        GCH1                         DOPA-responsive dystonia
# 2        3         PTS  6-pyruvoyl-tetrahydropterin synthase deficiency
# 3        4         SPR                 Sepiapterin reductase deficiency
# 4        5        TETB            Dihydropteridine reductase deficiency
# ...    ...         ...                                              ...
# 2352  2353        TDH6                      Thyroid dyshormonogenesis 6
# 2353  2354      VDDR1A         Hypocalcemic vitamin D-dependent rickets
# 2354  2355       VDDR3              Vitamin D-dependent rickets, type 3
# 2355  2356       VDEGS                      Van den Ende-Gupta syndrome
# 2356  2357        ZLS2                       Zimmermann-Laband syndrome
#
#                                              diseaseSyn diseaseSource  \
# 0                                                   NaN         ICIMD
# 1                                        Segawa disease         ICIMD
# 2               PTS-associated atypical phenylketonuria         ICIMD
# 3               SPR-associated atypical phenylketonuria         ICIMD
# 4              QDPR-associated atypical phenylketonuria         ICIMD
# ...                                                 ...           ...
# 2352                 Familial thyroid dyshormonogenesis          OMIM
# 2353                                                NaN          OMIM
# 2354           Hypocalcemic vitamin D-resistant rickets          OMIM
# 2355                                                NaN          OMIM
# 2356  Gingival fibromatosis-hepatosplenomegaly-other...          OMIM
#
#                                      diseaseDescription  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 2352  Familial thyroid dyshormonogenesis is a type o...
# 2353  An early-onset hereditary vitamin D metabolism...
# 2354  Hypocalcemic vitamin D-resistant rickets (HVDR...
# 2355  Van den Ende Gupta syndrome is present at birt...
# 2356  A rare genetic multiple congenital anomalies s...
#
#                       diseaseType icimdNosologyNumber gene_id omimGene  ...  \
# 0     Inherited metabolic disease          21.1.02.01    2643   600225  ...
# 1     Inherited metabolic disease          21.1.03.01    2643      NaN  ...
# 2     Inherited metabolic disease          21.1.04.01    5805   612719  ...
# 3     Inherited metabolic disease          21.1.05.01    6697   182125  ...
# 4     Inherited metabolic disease          21.1.06.01    5860   612676  ...
# ...                           ...                 ...     ...      ...  ...
# 2352                          NaN                 NaN   50506   606759  ...
# 2353                          NaN                 NaN    1594   609506  ...
# 2354                          NaN                 NaN    1576   124010  ...
# 2355                          NaN                 NaN   91179   613619  ...
# 2356                          NaN                 NaN     526   606939  ...
#
#          gard genereviews clingendosage   igsr1000genoms gwascataloge  \
# 0         NaN         NaN          GCH1              NaN         GCH1
# 1         NaN         NaN           NaN              NaN          NaN
# 2         NaN         NaN           PTS              NaN          PTS
# 3         NaN         NaN           SPR              NaN          SPR
# 4      5682.0         NaN          QDPR  ENSG00000151552         QDPR
# ...       ...         ...           ...              ...          ...
# 2352  16843.0         NaN           NaN              NaN          NaN
# 2353  17319.0         NaN           NaN              NaN          NaN
# 2354  16805.0         NaN           NaN              NaN          NaN
# 2355   3382.0         NaN           NaN              NaN          NaN
# 2356    385.0         NaN           NaN              NaN          NaN
#
#      gwascentral  geno2mp clinvar  lovd                        malacard
# 0           GCH1     GCH1  600225  GCH1                             NaN
# 1            NaN      NaN     NaN   NaN                             NaN
# 2            PTS      PTS  612719   PTS                             NaN
# 3            SPR      SPR  182125   SPR                             NaN
# 4           QDPR     QDPR  612676  QDPR  tetrahydrobiopterin_deficiency
# ...          ...      ...     ...   ...                             ...
# 2352         NaN      NaN     NaN   NaN                             NaN
# 2353         NaN      NaN     NaN   NaN                             NaN
# 2354         NaN      NaN     NaN   NaN                             NaN
# 2355         NaN      NaN     NaN   NaN                             NaN
# 2356         NaN      NaN     NaN   NaN                             NaN
#
# [2357 rows x 39 columns]

# %%
known_imds = pd.read_csv(base_path / "reconws_diseases.csv")
known_imds = known_imds[~known_imds['omimDisease'].isna()]
known_imds['omimDisease'] = known_imds['omimDisease'].astype(int)
known_imds = known_imds[(known_imds['diseaseSource'] == 'ICIMD') | (known_imds['diseaseSource'] == 'IEMBASE')]
known_imds = known_imds['omimDisease'].unique()

# -----------------------------------------------
# known_imds  =  list / set of OMIM integers
# prompts_df  =  your original DataFrame
# -----------------------------------------------

# 1) how many rows for each diagnosis
counts = prompts_df["Correct Diagnosis"].value_counts()

# 2) first (or only) OMIM code associated with each diagnosis
diag2omim = (
    prompts_df
        .groupby("Correct Diagnosis", as_index=True)["OMIM"]
        .first()                       # <-- pick the first non-NA per group
)

# 3) build the final table
counts_df = (
    counts
        .to_frame("count")             # make it a DataFrame, column name = "count"
        .join(diag2omim)               # adds a second column called "OMIM"
        .assign(in_known_imd = lambda t: t["OMIM"].isin(known_imds))
)

print(counts_df.head())
# Out:
#                                                     count    OMIM  \
# Correct Diagnosis
# Developmental and epileptic encephalopathy 4          411  612164
# KBG syndrome                                          308  148050
# Developmental and epileptic encephalopathy 11         265  613721
# Glass syndrome                                        143  612313
# Mitochondrial DNA depletion syndrome 13 (enceph...     92  615471
#
#                                                     in_known_imd
# Correct Diagnosis
# Developmental and epileptic encephalopathy 4                True
# KBG syndrome                                               False
# Developmental and epileptic encephalopathy 11              False
# Glass syndrome                                             False
# Mitochondrial DNA depletion syndrome 13 (enceph...          True

# %%
df = counts_df

latex_table = (
    df.reset_index()                       # 1. move index → column
      .rename(columns={
          "index": "Diagnosis",            # new text column
          "count": "Count",
          "in_known_imd": "Known IMD"      # rename the flag
      })
      .drop(columns=["OMIM"])              # (optional) omit OMIM if you prefer
      .assign(**{                          # 2. prettify the flag
          "Known IMD": lambda t: t["Known IMD"].map({True: "Yes", False: "No"})
      })
      .to_latex(
          index=False, escape=False,
          longtable=True,
          column_format="p{7cm}rr",
          caption="Disease frequencies and IMD status",
          label="tab:disease_counts"
      )
)

print(latex_table)
# Out:
# \begin{longtable}{p{7cm}rr}
# \caption{Disease frequencies and IMD status} \label{tab:disease_counts} \\
# \toprule
# Correct Diagnosis & Count & Known IMD \\
# \midrule
# \endfirsthead
# \caption[]{Disease frequencies and IMD status} \\
# \toprule
# Correct Diagnosis & Count & Known IMD \\
# \midrule
# \endhead
# \midrule
# \multicolumn{3}{r}{Continued on next page} \\
# \midrule
# \endfoot
# \bottomrule
# \endlastfoot
# Developmental and epileptic encephalopathy 4  & 411 & Yes \\
# KBG syndrome  & 308 & No \\
# Developmental and epileptic encephalopathy 11  & 265 & No \\
# Glass syndrome  & 143 & No \\
# Mitochondrial DNA depletion syndrome 13 (encephalomyopathic type)  & 92 & Yes \\
# Holt-Oram syndrome  & 72 & No \\
# Neurodevelopmental disorder with coarse facies and mild distal skeletal abnormalities  & 65 & No \\
# Kabuki Syndrome 1  & 65 & Yes \\
# Coffin-Siris syndrome 8  & 62 & No \\
# Jacobsen syndrome  & 60 & No \\
# Houge-Janssen syndrome 2  & 53 & No \\
# ZTTK SYNDROME  & 50 & No \\
# Mitochondrial DNA depletion syndrome 6 (hepatocerebral type)  & 48 & No \\
# Developmental delay dysmorphic facies and brain anomalies  & 47 & No \\
# Intellectual developmental disorder autosomal dominant 21  & 46 & No \\
# Hypomagnesemia 3 renal  & 45 & No \\
# Marfan syndrome  & 44 & Yes \\
# Greig cephalopolysyndactyly syndrome  & 44 & No \\
# Cardiac facial and digital anomalies with developmental delay  & 44 & No \\
# Developmental and epileptic encephalopathy 28  & 43 & No \\
# Loeys-Dietz syndrome 3  & 42 & No \\
# Emery-Dreifuss muscular dystrophy 2 autosomal dominant  & 41 & No \\
# Leber congenital amaurosis 6  & 40 & No \\
# Loeys-Dietz syndrome 5  & 35 & No \\
# Cardiomyopathy dilated 1A  & 33 & No \\
# Kufor-Rakeb syndrome  & 31 & Yes \\
# Seizures benign familial infantile 3  & 30 & No \\
# Ehlers-Danlos syndrome vascular type  & 30 & Yes \\
# Loeys-Dietz syndrome 4  & 30 & No \\
# Intellectual developmental disorder X-linked 112  & 28 & No \\
# Spastic ataxia 8 autosomal recessive with hypomyelinating leukodystrophy  & 28 & No \\
# HMG-CoA synthase-2 deficiency  & 28 & Yes \\
# LEOPARD syndrome 1  & 26 & No \\
# Robinow syndrome autosomal recessive  & 25 & No \\
# Albinism oculocutaneous type IV  & 25 & No \\
# Ectopia lentis familial  & 25 & Yes \\
# Mitochondrial complex IV deficiency nuclear type 2  & 25 & Yes \\
# Acrofacial dysostosis 1 Nager type  & 24 & No \\
# Spastic paraplegia 91 autosomal dominant with or without cerebellar ataxia  & 23 & No \\
# Sulfite oxidase deficiency  & 23 & Yes \\
# Hypotonia infantile with psychomotor retardation and characteristic facies 3  & 23 & No \\
# Noonan syndrome 1  & 23 & No \\
# Developmental and epileptic encephalopathy 5  & 21 & No \\
# Myoclonic epilepsy of Lafora 2  & 20 & No \\
# Noonan syndrome 2  & 20 & No \\
# Ataxia-pancytopenia syndrome  & 20 & No \\
# Pallister-Hall syndrome  & 20 & No \\
# Intellectual developmental disorder with dysmorphic facies and behavioral abnormalities  & 20 & No \\
# Loeys-Dietz syndrome 2  & 19 & Yes \\
# EZH1-related neurodevelopmental disorder  & 19 & No \\
# Developmental and epileptic encephalopathy 112  & 19 & No \\
# Neurodevelopmental disorder with or without anomalies of the brain eye or heart  & 18 & No \\
# Autoinflammatory syndrome familial with or without immunodeficiency  & 18 & No \\
# Neurodevelopmental disorder with or without variable brain abnormalities  & 18 & No \\
# Acrofacial dysostosis Cincinnati type  & 18 & Yes \\
# Geleophysic dysplasia 2  & 17 & Yes \\
# Vici syndrome  & 17 & Yes \\
# Marfan lipodystrophy syndrome  & 17 & Yes \\
# Anemia sideroblastic and spinocerebellar ataxia  & 17 & Yes \\
# Aarskog-Scott syndrome  & 16 & No \\
# Developmental delay with or without epilepsy  & 16 & No \\
# Multiple mitochondrial dysfunctions syndrome 4  & 16 & Yes \\
# Cornelia de Lange syndrome 6  & 15 & No \\
# Metabolic encephalomyopathic crises, recurrent, with rhabdomyolysis, cardiac arrhythmias, and neurodegeneration & 15 & Yes \\
# Loeys-Dietz syndrome 6  & 15 & No \\
# LMNA-related congenital muscular dystrophy  & 15 & No \\
# Hutchinson-Gilford progeria  & 15 & No \\
# Neurodegeneration with brain iron accumulation 1  & 15 & No \\
# Distal renal tubular acidosis 1  & 15 & No \\
# Coffin-Siris syndrome 3  & 15 & No \\
# Microphthalmia/coloboma 11  & 15 & No \\
# Spastic paraplegia 76 autosomal recessive  & 14 & No \\
# Muscular dystrophy limb-girdle autosomal recessive 28  & 14 & No \\
# Epilepsy, early-onset, 3, with or without developmental delay & 14 & No \\
# Neuronopathy distal hereditary motor autosomal dominant 11  & 14 & No \\
# Neurodevelopmental disorder with progressive microcephaly spasticity and brain anomalies  & 14 & No \\
# Neurodevelopmental disorder with intracranial hemorrhage seizures and spasticity  & 13 & No \\
# Acromicric dysplasia  & 13 & Yes \\
# Immunoskeletal dysplasia with neurodevelopmental abnormalitie  & 13 & Yes \\
# Hyper-IgE syndrome 2 autosomal recessive with recurrent infections  & 13 & No \\
# Nephrotic syndrome type 5 with or without ocular abnormalities  & 13 & Yes \\
# Myhre syndrome  & 12 & No \\
# Arrhythmogenic cardiomyopathy with variable ectodermal abnormalities  & 12 & No \\
# Intellectual developmental disorder autosomal dominant 74  & 12 & No \\
# Contractural arachnodactyly congenital  & 12 & Yes \\
# Parkinson disease 15 autosomal recessive  & 12 & No \\
# Neurodevelopmental disorder with motor and language delay ocular defects and brain abnormalities  & 12 & No \\
# Neurodevelopmental disorder with impaired language behavioral abnormalities and dysmorphic facies  & 12 & No \\
# Lipodystrophy familial partial type 2  & 12 & No \\
# Bardet-Biedl syndrome 1  & 12 & No \\
# Rabin-Pappas syndrome  & 12 & No \\
# Spinocerebellar ataxia 15  & 12 & Yes \\
# Noonan syndrome 6  & 11 & No \\
# Autoimmune polyendocrinopathy syndrome type I with or without reversible metaphyseal dysplasia  & 11 & No \\
# Spastic paraplegia 78 autosomal recessive  & 11 & No \\
# Neurodevelopmental disorder with hypotonia and speech delay with or without seizures  & 11 & No \\
# Intellectual developmental disorder autosomal dominant 70  & 11 & No \\
# Spastic ataxia 10 autosomal recessive  & 10 & No \\
# Boucher-Neuhauser syndrome  & 10 & No \\
# Intellectual developmental disorder autosomal dominant 73  & 10 & No \\
# Cockayne syndrome type A  & 10 & No \\
# Loeys-Dietz syndrome 1  & 10 & Yes \\
# Immunodeficiency common variable 15  & 10 & No \\
# Fliedner-Zweier syndrome  & 10 & No \\
# Arthrogryposis distal with impaired proprioception and touch  & 10 & No \\
# Opsismodysplasia  & 9 & Yes \\
# Spinocerebellar ataxia autosomal recessive 20  & 9 & Yes \\
# Multiple mitochondrial dysfunctions syndrome 7  & 9 & No \\
# Treacher Collins syndrome 2  & 9 & Yes \\
# Neurodevelopmental disorder with motor regression progressive spastic paraplegia and oromotor dysfunction  & 9 & No \\
# Cone-rod dystrophy 13  & 9 & No \\
# Acromelic frontonasal dysostosis  & 9 & No \\
# Wolfram syndrome 1  & 9 & Yes \\
# Diamond-Blackfan anemia 1  & 9 & Yes \\
# Myasthenic syndrome, congenital, 9, associated with acetylcholine receptor deficiency & 8 & No \\
# Neuronopathy distal hereditary motor autosomal recessive 10  & 8 & No \\
# Orofaciodigital syndrome V  & 8 & No \\
# CODAS syndrome  & 8 & Yes \\
# Cleidocranial dysplasia  & 8 & No \\
# Retinitis pigmentosa with or without skeletal anomalies  & 8 & No \\
# Structural heart defects and renal anomalies syndrome  & 8 & Yes \\
# Al Kaissi syndrome  & 8 & No \\
# Joubert syndrome 10  & 8 & No \\
# Developmental and epileptic encephalopathy 14  & 8 & No \\
# Retinitis pigmentosa 11  & 8 & No \\
# Thrombocytopenia 8 with dysmorphic features and developmental delay  & 7 & No \\
# Tuberous sclerosis-2  & 7 & No \\
# Spherocytosis type 4  & 7 & No \\
# Combined oxidative phosphorylation deficiency 58  & 7 & Yes \\
# Glutaricaciduria type I  & 7 & Yes \\
# Neurodevelopmental disorder with movement abnormalities abnormal gait and autistic features  & 7 & No \\
# Oliver-McFarlane syndrome  & 7 & No \\
# Thrombocytopenia 3  & 7 & No \\
# Oculopharyngeal muscular dystrophy 2  & 7 & No \\
# Lipodystrophy familial partial type 9  & 7 & No \\
# Cortical dysplasia, complex, with other brain malformations 14A, (bilateral frontoparietal) & 7 & No \\
# Neurofibromatosis type 1  & 7 & No \\
# Developmental and epileptic encephalopathy 111  & 7 & No \\
# Congenital disorder of glycosylation type Iip  & 7 & Yes \\
# Distal renal tubular acidosis 4 with hemolytic anemia  & 7 & No \\
# Bamforth-Lazarus syndrome  & 7 & No \\
# Noonan syndrome 3  & 7 & No \\
# Microcephaly short stature and polymicrogyria with seizures  & 7 & No \\
# Branchiooculofacial syndrome  & 7 & No \\
# Myopathy distal Tateyama type  & 7 & No \\
# Orofaciodigital syndrome I  & 6 & No \\
# Craniometadiaphyseal osteosclerosis with hip dysplasia  & 6 & No \\
# Cutis laxa autosomal recessive type IIC  & 6 & Yes \\
# Neuronopathy distal hereditary motor autosomal recessive 9  & 6 & No \\
# Craniofrontonasal dysplasia  & 6 & No \\
# Immunodeficiency 118 mycobacteriosis  & 6 & No \\
# Ectodermal dysplasia 9 hair/nail type  & 6 & No \\
# Polymicrogyria with or without vascular-type EDS  & 6 & Yes \\
# Polydactyly postaxial types A1 and B  & 6 & No \\
# STAR syndrome  & 6 & No \\
# Van den Ende-Gupta syndrome  & 6 & No \\
# Chitayat syndrome  & 6 & No \\
# Sick sinus syndrome 2  & 6 & No \\
# Stiff skin syndrome  & 6 & Yes \\
# Branched-chain keto acid dehydrogenase kinase deficiency  & 6 & Yes \\
# Craniometaphyseal dysplasia  & 5 & No \\
# Ehlers-Danlos syndrome classic-like 2  & 5 & No \\
# Cutis laxa autosomal recessive type IA  & 5 & No \\
# Prolonged electroretinal response suppression 1  & 5 & No \\
# DiGeorge syndrome  & 5 & No \\
# Ullrich congenital muscular dystrophy 1C  & 5 & No \\
# Neurodevelopmental disorder with motor abnormalities seizures and facial dysmorphism  & 5 & No \\
# Tuberous sclerosis-1  & 5 & No \\
# Birt-Hogg-Dube syndrome 2  & 5 & No \\
# Spondyloepimetaphyseal dysplasia Guo-Campeau type  & 5 & No \\
# Deafness autosomal recessive 123  & 5 & No \\
# Congenital disorder of glycosylation type Il  & 5 & Yes \\
# Neurodegeneration with brain iron accumulation 9  & 5 & No \\
# Spastic paraplegia 10 autosomal dominant  & 5 & Yes \\
# CHARGE syndrome  & 5 & No \\
# Thrombocytopenia 11 with multiple congenital anomalies and dysmorphic facies  & 5 & No \\
# Arthrogryposis distal type 12  & 5 & No \\
# Progressive external ophthalmoplegia with mitochondrial DNA deletions autosomal recessive 6  & 5 & Yes \\
# Cutis laxa autosomal recessive type ID  & 4 & Yes \\
# Congenital disorder of glycosylation type IIh  & 4 & Yes \\
# Ichthyosis congenital autosomal recessive 11  & 4 & No \\
# Fanconi anemia complementation group I  & 4 & No \\
# Hoxha-Aliu syndrome  & 4 & No \\
# Bardet-Biedl syndrome 2  & 4 & No \\
# Fanconi anemia complementation group C  & 4 & No \\
# Alfadhel syndrome  & 4 & No \\
# Bethlem myopathy 1A  & 4 & Yes \\
# Premature ovarian failure 23  & 4 & No \\
# Autoinflammatory disease systemic with vasculitis  & 4 & No \\
# Bardet-Biedl syndrome 5  & 4 & No \\
# Neuropathy hereditary sensory and autonomic type IIB  & 4 & No \\
# Neurodevelopmental disorder with hyperkinetic movements seizures and structural brain abnormalities  & 4 & Yes \\
# Immunodeficiency 114 folate-responsive  & 4 & Yes \\
# Developmental and epileptic encephalopathy 9  & 4 & No \\
# Developmental and epileptic encephalopathy 114  & 4 & No \\
# Prolonged electroretinal response suppression 2  & 4 & No \\
# Treacher Collins syndrome 1  & 4 & Yes \\
# Neurodevelopmental disorder with language delay and variable cognitive abnormalities  & 4 & No \\
# Rett syndrome congenital variant  & 4 & No \\
# Epidermolytic hyperkeratosis 2B autosomal recessive  & 4 & No \\
# Xerosis and growth failure with immune and pulmonary dysfunction syndrome  & 4 & No \\
# Leukodystrophy hypomyelinating 27  & 4 & No \\
# Congenital disorder of glycosylation type IIbb  & 4 & No \\
# Homocystinuria B6-responsive and nonresponsive types  & 4 & Yes \\
# Spinocerebellar ataxia autosomal recessive 12  & 4 & No \\
# Retinitis pigmentosa 76  & 4 & No \\
# Auriculocondylar syndrome 2B  & 4 & No \\
# Tan-Almurshedi syndrome  & 4 & No \\
# Citrullinemia  & 4 & Yes \\
# Long QT syndrome 14  & 4 & No \\
# Corneal dystrophy Fuchs endothelial 4  & 4 & No \\
# Bleeding disorder vascular-type  & 3 & No \\
# Larsen syndrome  & 3 & No \\
# Intellectual developmental disorder autosomal recessive 18 with or without epilepsy  & 3 & No \\
# Bardet-Biedl syndrome 4  & 3 & No \\
# Combined oxidative phosphorylation deficiency 59  & 3 & Yes \\
# Parkinson disease 23 autosomal recessive early onset  & 3 & Yes \\
# Ciliary dyskinesia primary 53  & 3 & No \\
# Osteogenesis imperfecta type XIV  & 3 & No \\
# Autoimmune disease, multisystem, infantile-onset, 3 & 3 & No \\
# Maple syrup urine disease type Ib  & 3 & No \\
# Keratoderma palmoplantar punctate type IA  & 3 & Yes \\
# Megalencephaly-polydactyly syndrome  & 3 & No \\
# Ciliary dyskinesia primary 52  & 3 & No \\
# Polydactyly-macrocephaly syndrome  & 3 & No \\
# Lipodystrophy familial partial type 8  & 3 & No \\
# Hemophagocytic lymphohistiocytosis familial 2  & 3 & No \\
# Ventricular tachycardia catecholaminergic polymorphic 3  & 3 & No \\
# Noonan syndrome-11  & 3 & No \\
# Retinitis pigmentosa 78  & 3 & No \\
# Luscan-Lumish syndrome  & 3 & No \\
# Donohue syndrome  & 3 & No \\
# Intellectual developmental disorder autosomal recessive 80 with variant lissencephaly  & 3 & No \\
# Spastic paraplegia 7 autosomal recessive  & 3 & Yes \\
# Pulmonary fibrosis and/or bone marrow failure syndrome telomere-related 8  & 3 & No \\
# Intellectual developmental disorder autosomal recessive 82  & 3 & No \\
# Lathosterolosis  & 3 & Yes \\
# Immunodeficiency 112  & 3 & No \\
# Retinitis pigmentosa 18  & 2 & No \\
# Severe combined immunodeficiency due to ADA deficiency  & 2 & Yes \\
# Microcephaly 6 primary autosomal recessive  & 2 & No \\
# Werner syndrome  & 2 & No \\
# Holoprosencephaly 4  & 2 & No \\
# Immunodeficiency 115 with autoinflammation  & 2 & Yes \\
# Developmental and epileptic encephalopathy 113  & 2 & No \\
# Cardiomyopathy, familial hypertrophic, 30, atrial & 2 & No \\
# Short QT syndrome 3  & 2 & No \\
# Dystonia 22 adult-onset  & 2 & No \\
# Mucolipidosis IV  & 2 & Yes \\
# Diabetes, deafness, developmental delay, and short stature syndrome & 2 & No \\
# Heterotaxy, visceral, 1, X-linked & 2 & No \\
# Yuksel-Vogel-Bauser syndrome  & 2 & No \\
# Congenital disorder of glycosylation type IIc  & 2 & Yes \\
# Bethlem myopathy 1C  & 2 & No \\
# Neurodegeneration childhood-onset with cerebellar ataxia and cognitive decline  & 2 & No \\
# Brugada syndrome 1  & 2 & No \\
# Cohen syndrome  & 2 & Yes \\
# Smith-Magenis syndrome  & 2 & No \\
# Arthrogryposis distal type 2A (Freeman-Sheldon)  & 2 & No \\
# Trichohepatoenteric syndrome 1  & 2 & No \\
# Spastic paraplegia 45 autosomal recessive  & 2 & No \\
# Choreoacanthocytosis  & 2 & Yes \\
# Cutis laxa autosomal recessive type IID  & 2 & No \\
# Osteogenesis imperfecta type XI  & 2 & No \\
# Hypotrichosis congenital with juvenile macular dystrophy  & 2 & No \\
# Cornelia de Lange syndrome 3  & 2 & No \\
# Vasculitis, autoinflammation, immunodeficiency, and hematologic defects syndrome & 2 & Yes \\
# Nemaline myopathy 7 autosomal recessive  & 2 & No \\
# Jervell and Lange-Nielsen syndrome  & 2 & No \\
# Immunodeficiency 133 with autoimmunity and autoinflammation  & 2 & No \\
# Optic atrophy 16  & 2 & Yes \\
# Lipodystrophy congenital generalized type 5  & 2 & Yes \\
# Chudley-McCullough syndrome  & 2 & No \\
# Pseudoachondroplasia  & 2 & Yes \\
# Apert syndrome  & 2 & No \\
# Spondylocostal dysostosis 1 autosomal recessive  & 2 & No \\
# GM1-gangliosidosis type III  & 2 & No \\
# Spastic paraplegia 90A autosomal dominant  & 2 & No \\
# Alzheimer disease-4  & 2 & No \\
# Garg-Mishra progeroid syndrome  & 2 & Yes \\
# Waardenburg syndrome type 3  & 2 & No \\
# Holoprosencephaly 5  & 2 & No \\
# Stickler syndrome type II  & 2 & Yes \\
# Long QT syndrome 15  & 2 & No \\
# Dystonia 37 early-onset with striatal lesions  & 1 & No \\
# Tietz albinism-deafness syndrome  & 1 & No \\
# Tubulointerstitial kidney disease autosomal dominant 1  & 1 & No \\
# Ehlers-Danlos syndrome classic type 1  & 1 & Yes \\
# Lui-Jee-Baron syndrome  & 1 & No \\
# Maple syrup urine disease type II  & 1 & No \\
# Retinitis pigmentosa 19  & 1 & No \\
# Immunodeficiency 117 mycobacteriosis autosomal recessive  & 1 & No \\
# Spastic paraplegia 90B autosomal recessive  & 1 & No \\
# Spherocytosis type 5  & 1 & No \\
# Palmoplantar keratoderma epidermolytic 1  & 1 & No \\
# Cardiofaciocutaneous syndrome 2  & 1 & No \\
# Charcot-Marie-Tooth disease axonal type 2A2A  & 1 & Yes \\
# Glycogen storage disease VI  & 1 & Yes \\
# Cortical dysplasia complex with other brain malformations 7  & 1 & No \\
# Pierpont syndrome  & 1 & No \\
# Smith-Lemli-Opitz syndrome  & 1 & Yes \\
# Ayme-Gripp syndrome  & 1 & No \\
# Chediak-Higashi syndrome  & 1 & Yes \\
# Legius syndrome  & 1 & No \\
# Albinism oculocutaneous type III  & 1 & No \\
# Niemann-Pick disease type C1  & 1 & Yes \\
# Smith-Kingsmore syndrome  & 1 & No \\
# Spinocerebellar ataxia 29 congenital nonprogressive  & 1 & No \\
# Ehlers-Danlos syndrome classic type 2  & 1 & Yes \\
# Parkinson disease 7 autosomal recessive early-onset  & 1 & No \\
# Amelogenesis imperfecta type IA  & 1 & No \\
# Amyloidosis Finnish type  & 1 & No \\
# Neutropenia, severe congenital, 11, autosomal dominant & 1 & No \\
# Muenke syndrome  & 1 & No \\
# Krabbe disease  & 1 & Yes \\
# Hajdu-Cheney syndrome  & 1 & No \\
# Trichorhinophalangeal syndrome type I  & 1 & No \\
# Multiple endocrine neoplasia 1  & 1 & No \\
# Immunodeficiency 103 susceptibility to fungal infection  & 1 & No \\
# Acromesomelic dysplasia 1 Maroteaux type  & 1 & No \\
# Microcephaly 3 primary autosomal recessive  & 1 & No \\
# Developmental and epileptic encephalopathy 17   & 1 & No \\
# Bleeding disorder platelet-type 15  & 1 & No \\
# Megalocornea 1 X-linked  & 1 & No \\
# Weill-Marchesani syndrome 1 recessive  & 1 & Yes \\
# Congenital myopathy 4B autosomal recessive  & 1 & No \\
# Galactosialidosis  & 1 & Yes \\
# Cerebral dysgenesis, neuropathy, ichthyosis, and palmoplantar keratoderma syndrome & 1 & Yes \\
# Neuropathy recurrent with pressure palsies  & 1 & No \\
# Intellectual developmental disorder autosomal dominant 42  & 1 & No \\
# Hyper-IgE syndrome 1 autosomal dominant with recurrent infections  & 1 & No \\
# 3-methylglutaconic aciduria with deafness encephalopathy and Leigh-like syndrome  & 1 & Yes \\
# Spinal muscular atrophy with progressive myoclonic epilepsy  & 1 & No \\
# Leukocyte adhesion deficiency type III  & 1 & No \\
# Nail-patella syndrome  & 1 & No \\
# Hypochondroplasia  & 1 & No \\
# Cholestasis progressive familial intrahepatic 4  & 1 & No \\
# Congenital myopathy 2A typical autosomal dominant  & 1 & No \\
# Kabuki syndrome 2  & 1 & Yes \\
# Cerebral creatine deficiency syndrome 1  & 1 & Yes \\
# Intellectual developmental disorder with dysmorphic facies seizures and distal limb anomalies  & 1 & No \\
# Cardiofaciocutaneous syndrome  & 1 & No \\
# Ehlers-Danlos syndrome musculocontractural type 1  & 1 & Yes \\
# Amyotrophic lateral sclerosis 1  & 1 & Yes \\
# Cockayne syndrome type B  & 1 & No \\
# Ectodermal dysplasia 1 hypohidrotic X-linked  & 1 & No \\
# Cone-rod retinal dystrophy-2 AD 3  & 1 & No \\
# Hyaline fibromatosis syndrome  & 1 & No \\
# Alagille syndrome 1  & 1 & No \\
# Osteogenesis imperfecta type XV  & 1 & No \\
# Dyskeratosis congenita autosomal dominant 3  & 1 & No \\
# Inclusion body myopathy with early-onset Paget disease and frontotemporal dementia 1  & 1 & No \\
# Renal cysts and diabetes syndrome  & 1 & No \\
# Myasthenic syndrome congenital 22  & 1 & No \\
# Fibrodysplasia ossificans progressiva  & 1 & No \\
# Myopathy myofibrillar 3  & 1 & No \\
# Osteogenesis imperfecta type XII  & 1 & No \\
# Charcot-Marie-Tooth disease type 1C  & 1 & No \\
# Schinzel-Giedion midface retraction syndrome  & 1 & No \\
# Cryohydrocytosis  & 1 & No \\
# Poikiloderma with neutropenia  & 1 & No \\
# \end{longtable}

# %%
# Count how many times each disease appears
disease_counts = prompts_df['Correct Diagnosis'].value_counts()

# Calculate mean and standard deviation
mean_per_disease = disease_counts.mean()
std_per_disease = disease_counts.std()

print(f"Average entries per disease: {mean_per_disease:.2f}")
print(f"Standard deviation: {std_per_disease:.2f}")
# Out:
# Average entries per disease: 12.24
# Standard deviation: 32.86

# %%
prompts_df = prompts_df.dropna()
prompts_df['OMIM'] = prompts_df['OMIM'].astype(int)
prompts_df
# Out:
#                                                                        Case Description  \
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  The proband was a female. Disease onset was no...
# PMID_10571775_YAT_II_1_en-prompt.txt  The proband was a male. Disease onset was not ...
# PMID_10580070_A_III_11_en-prompt.txt  The proband was a female. Disease onset occurr...
# PMID_10580070_A_III_13_en-prompt.txt  The proband was a male. Disease onset occurred...
# PMID_10580070_A_III_5_en-prompt.txt   The proband was a female. Disease onset occurr...
# ...                                                                                 ...
# STX_Syrbe_3_en-prompt.txt             The proband was a 5-year, 0-month old child. D...
# STX_Syrbe_4_en-prompt.txt             The proband was a 6-year, 0-month old child. D...
# STX_Syrbe_5_en-prompt.txt             The proband was a 4-year, 0-month old child. D...
# STX_Syrbe_6_en-prompt.txt             The proband was a 2-year, 0-month old child. D...
# STX_Syrbe_8_en-prompt.txt             The proband was a 4-year, 0-month old child. D...
#
#                                                                       Correct Diagnosis  \
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  Distal renal tubular acidosis 4 with hemolytic...
# PMID_10571775_YAT_II_1_en-prompt.txt  Distal renal tubular acidosis 4 with hemolytic...
# PMID_10580070_A_III_11_en-prompt.txt                         Cardiomyopathy dilated 1A
# PMID_10580070_A_III_13_en-prompt.txt                         Cardiomyopathy dilated 1A
# PMID_10580070_A_III_5_en-prompt.txt                          Cardiomyopathy dilated 1A
# ...                                                                                 ...
# STX_Syrbe_3_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_4_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_5_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_6_en-prompt.txt                 Developmental and epileptic encephalopathy 4
# STX_Syrbe_8_en-prompt.txt                 Developmental and epileptic encephalopathy 4
#
#                                         OMIM  \
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  611590
# PMID_10571775_YAT_II_1_en-prompt.txt  611590
# PMID_10580070_A_III_11_en-prompt.txt  115200
# PMID_10580070_A_III_13_en-prompt.txt  115200
# PMID_10580070_A_III_5_en-prompt.txt   115200
# ...                                      ...
# STX_Syrbe_3_en-prompt.txt             612164
# STX_Syrbe_4_en-prompt.txt             612164
# STX_Syrbe_5_en-prompt.txt             612164
# STX_Syrbe_6_en-prompt.txt             612164
# STX_Syrbe_8_en-prompt.txt             612164
#
#                                                                       PMID
# File Name
# PMID_10571775_KSN_II_1_en-prompt.txt  PMID_10571775_KSN_II_1_en-prompt.txt
# PMID_10571775_YAT_II_1_en-prompt.txt  PMID_10571775_YAT_II_1_en-prompt.txt
# PMID_10580070_A_III_11_en-prompt.txt  PMID_10580070_A_III_11_en-prompt.txt
# PMID_10580070_A_III_13_en-prompt.txt  PMID_10580070_A_III_13_en-prompt.txt
# PMID_10580070_A_III_5_en-prompt.txt    PMID_10580070_A_III_5_en-prompt.txt
# ...                                                                    ...
# STX_Syrbe_3_en-prompt.txt                        STX_Syrbe_3_en-prompt.txt
# STX_Syrbe_4_en-prompt.txt                        STX_Syrbe_4_en-prompt.txt
# STX_Syrbe_5_en-prompt.txt                        STX_Syrbe_5_en-prompt.txt
# STX_Syrbe_6_en-prompt.txt                        STX_Syrbe_6_en-prompt.txt
# STX_Syrbe_8_en-prompt.txt                        STX_Syrbe_8_en-prompt.txt
#
# [4419 rows x 4 columns]

# %%
prompts_df = prompts_df.loc[preds['file_name'].unique()]

# %%
# %% [markdown]
# # Minimal GPT‑4o → OMIM demo
# One test case, no synonym table.

# %%
# 0  Install deps  (uncomment the next line the very first time)
# !pip install --quiet openai==1.* tqdm pandas

# %%
import json, os, math
import pandas as pd
import openai
from tqdm.auto import tqdm

openai.api_key = os.getenv("OPENAI_KEY")   # ← set this in your shell:  export OPENAI_API_KEY="sk‑..."

MODEL_NAME    = "gpt-4o"   # or "gpt-4o" / "gpt-4o-128k"
TEMPERATURE   = 0               # deterministic runs
MAX_WORDS     = 150             # rationale limit

# %%
# 1  Define the function‑calling schema
function_def = {
    "name": "diagnose_patient",
    "description": "Return the OMIM diagnosis for one patient vignette.",
    "parameters": {
        "type": "object",
        "properties": {
            "omim_id":   { "type": "string",
                           "description": "6‑digit OMIM identifier you judge most likely" },
            "diagnosis": { "type": "string",
                           "description": "Human‑readable disease name chosen" },
            "rationale": { "type": "string",
                           "description": f"Explanation ≤{MAX_WORDS} words" },
            "confidence":{ "type": "number",
                           "description": "0–1 confidence this is correct" }
        },
        "required": ["omim_id"]
    }
}

# %%
# 2  Prompt template
prompt_tmpl = f"""You are an expert clinical geneticist.
Analyse the patient vignette and call the function `diagnose_patient`.

Guidelines:
• Pick **one** Mendelian disease (the single most likely).
• If uncertain, still return your best guess and set confidence <0.3.
• The rationale must be ≤{MAX_WORDS} words.

<CASE>
{{vignette}}
</CASE>
"""

# %%
# 3  Helper to call GPT‑4o
def gpt_diagnose(vignette):
    messages=[{"role":"system","content":prompt_tmpl.format(vignette=vignette)}]
    rsp = openai.chat.completions.create(
        model       = MODEL_NAME,
        temperature = TEMPERATURE,
        messages    = messages,
        functions   = [function_def],
    )
    fc = rsp.choices[0].message.function_call
    return json.loads(fc.arguments) if fc else {"omim_id":"","diagnosis":"", "rationale":"","confidence":0}

# %%
# 4  YOUR *single* test case goes here  ↓↓↓
# test_cases = [
#     {
#         "vignette": """
# A 15‑year‑old tall male with hyperextensible joints, high‑arched palate, 
# pectus excavatum, bilateral lens dislocation, and aortic root dilation 
# (4.8 cm). Family history reveals similarly affected father who died at 34 
# from aortic dissection.
# """,
#         "omim": "154700"          # ← the correct answer you expect (Marfan syndrome)
#     }
# ]

# %%
# 5  Run the benchmark
results = []
total_cases = 50
for case in tqdm(prompts_df.sample(total_cases).iterrows(), total=total_cases):
    pred = gpt_diagnose(case[1]["Case Description"])
    correct = str(pred["omim_id"]) == str(case[1]["OMIM"])
    results.append({
        "gold":       case[1]["OMIM"],
        "pred_id":    pred["omim_id"],
        "diagnosis":  pred.get("diagnosis",""),
        "correct diagnosis": case[1]["Correct Diagnosis"],
        "confidence": pred.get("confidence", math.nan),
        "correct":    correct,
        "rationale":  pred.get("rationale","")
    })

pd.DataFrame(results)
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
#       gold pred_id                                          diagnosis  \
# 0   102370  156200                       Léri-Weill dyschondrosteosis
# 1   604377  601238  Spinocerebellar Ataxia Type 3 (Machado-Joseph ...
# 2   617402  219200      Congenital Disorder of Glycosylation, Type II
# 3   613721  308350                      Allan-Herndon-Dudley syndrome
# 4   148050  610443            SYNGAP1-related intellectual disability
# 5   620535  194050                                  Williams Syndrome
# 6   268310  129400              Robinow syndrome, autosomal recessive
# 7   209900  209900                              Bardet-Biedl syndrome
# 8   620511  300624                              Mowat-Wilson syndrome
# 9   618362  616780                       Ohdo syndrome, SBBYS variant
# 10  613721  308350                      Allan-Herndon-Dudley syndrome
# 11  121050  114290                       Distal arthrogryposis type 1
# 12  620528  118220                Charcot-Marie-Tooth Disease Type 1A
# 13  616900  605802                      PTEN Hamartoma Tumor Syndrome
# 14  612164  300672  Joubert syndrome with cortical polymicrogyria ...
# 15  148050  147891                            Silver-Russell syndrome
# 16  614322  212700                              Ataxia-telangiectasia
# 17  613721  308350          X-linked Infantile Spasms Syndrome (ISSX)
# 18  148050  147920                         Cornelia de Lange Syndrome
# 19  620344  608096                                         Bradyopsia
# 20  130050  130070         Ehlers-Danlos syndrome, hypermobility type
# 21  601144  601144                                   Brugada syndrome
# 22  604377  601887  RYR1-Related Malignant Hyperthermia Susceptibi...
# 23  616462  192430                                    Noonan syndrome
# 24  612313  166200                     Osteogenesis Imperfecta Type I
# 25  154400  154780                             Townes-Brocks syndrome
# 26  618164  194190                                    Kabuki syndrome
# 27  227645  227650                                     Fanconi Anemia
# 28  612164  308350                                   Aicardi Syndrome
# 29  620666  184600                      Hereditary Spastic Paraplegia
# 30  618343  243310                          Dandy-Walker Malformation
# 31  614816  130000              Ehlers-Danlos Syndrome, Vascular Type
# 32  616878  308930                                     Barth syndrome
# 33  617140  194050                                    Noonan Syndrome
# 34  179800  267300               Distal Renal Tubular Acidosis (dRTA)
# 35  130050  130050              Ehlers-Danlos syndrome, vascular type
# 36  617140  612626                           Koolen-de Vries syndrome
# 37  612164  614756                         Kohlschütter-Tönz syndrome
# 38  256810  220290                                 Zellweger syndrome
# 39  248250  248250                                     Dent Disease 1
# 40  147791  182212                           Saethre-Chotzen syndrome
# 41  612164  308350                                   Aicardi Syndrome
# 42  616211  300672                          CDKL5 Deficiency Disorder
# 43  181350  158900                  Emery-Dreifuss Muscular Dystrophy
# 44  617694  180860                          Rubinstein-Taybi syndrome
# 45  613721  209850                                 Fragile X Syndrome
# 46  613721  308350                                   Aicardi Syndrome
# 47  613721  308350                      Allan-Herndon-Dudley syndrome
# 48  266265  610443                       Cornelia de Lange Syndrome 2
# 49  620669  234200  Neurodegeneration with Brain Iron Accumulation...
#
#                                     correct diagnosis  confidence  correct  \
# 0                               Acromicric dysplasia         0.30    False
# 1   Mitochondrial complex IV deficiency nuclear ty...        0.25    False
# 2            Cutis laxa autosomal recessive type IIC         0.70    False
# 3      Developmental and epileptic encephalopathy 11         0.60    False
# 4                                       KBG syndrome         0.30    False
# 5   Developmental delay dysmorphic facies and brai...        0.80    False
# 6               Robinow syndrome autosomal recessive         0.80    False
# 7                            Bardet-Biedl syndrome 1         0.60     True
# 8                           Fliedner-Zweier syndrome         0.60    False
# 9                            Coffin-Siris syndrome 8         0.30    False
# 10     Developmental and epileptic encephalopathy 11         0.30    False
# 11            Contractural arachnodactyly congenital         0.60    False
# 12  Neuronopathy distal hereditary motor autosomal...        0.30    False
# 13  Hypotonia infantile with psychomotor retardati...        0.60    False
# 14      Developmental and epileptic encephalopathy 4         0.30    False
# 15                                      KBG syndrome         0.70    False
# 16     Spinocerebellar ataxia autosomal recessive 12         0.30    False
# 17     Developmental and epileptic encephalopathy 11         0.60    False
# 18                                      KBG syndrome         0.30    False
# 19   Prolonged electroretinal response suppression 2         0.80    False
# 20              Ehlers-Danlos syndrome vascular type         0.60    False
# 21                                Brugada syndrome 1         0.70     True
# 22  Mitochondrial complex IV deficiency nuclear ty...        0.70    False
# 23             Acrofacial dysostosis Cincinnati type         0.60    False
# 24                                    Glass syndrome         0.30    False
# 25                Acrofacial dysostosis 1 Nager type         0.60    False
# 26  Cardiac facial and digital anomalies with deve...        0.70    False
# 27            Fanconi anemia complementation group C         0.90    False
# 28      Developmental and epileptic encephalopathy 4         0.70    False
# 29             Spastic ataxia 10 autosomal recessive         0.70    False
# 30  Polymicrogyria with or without vascular-type EDS         0.70    False
# 31                            Loeys-Dietz syndrome 4         0.30    False
# 32  Metabolic encephalomyopathic crises, recurrent...        0.30    False
# 33                                     ZTTK SYNDROME         0.25    False
# 34                   Distal renal tubular acidosis 1         0.90    False
# 35              Ehlers-Danlos syndrome vascular type         0.60     True
# 36                                     ZTTK SYNDROME         0.30    False
# 37      Developmental and epileptic encephalopathy 4         0.30    False
# 38  Mitochondrial DNA depletion syndrome 6 (hepato...        0.25    False
# 39                            Hypomagnesemia 3 renal         0.70     True
# 40                                 Jacobsen syndrome         0.30    False
# 41      Developmental and epileptic encephalopathy 4         0.30    False
# 42     Developmental and epileptic encephalopathy 28         0.60    False
# 43  Emery-Dreifuss muscular dystrophy 2 autosomal ...        0.80    False
# 44                                Al Kaissi syndrome         0.60    False
# 45     Developmental and epileptic encephalopathy 11         0.25    False
# 46     Developmental and epileptic encephalopathy 11         0.30    False
# 47     Developmental and epileptic encephalopathy 11         0.30    False
# 48     Congenital disorder of glycosylation type IIc         0.60    False
# 49  Neurodegeneration with brain iron accumulation 9         0.70    False
#
#                                             rationale
# 0   The proband's presentation of short stature, s...
# 1   The proband's symptoms, including tremor, stra...
# 2   The proband's symptoms align with a Congenital...
# 3   The clinical presentation of the patient is su...
# 4   The proband's symptoms of intellectual disabil...
# 5   The clinical features presented in the vignett...
# 6   The clinical features presented in the vignett...
# 7   The proband's symptoms, including postaxial po...
# 8   The proband's symptoms, including global devel...
# 9   The proband's features, including macrocephaly...
# 10  The symptoms presented in the vignette, includ...
# 11  The proband presents with camptodactyly of the...
# 12  The proband's symptoms are consistent with Cha...
# 13  The proband's symptoms of macrocephaly, develo...
# 14  The clinical presentation of the proband, incl...
# 15  The proband's presentation is suggestive of Si...
# 16  The proband's symptoms, including gait ataxia,...
# 17  The patient's symptoms, including focal-onset ...
# 18  The clinical features presented in the vignett...
# 19  The proband's symptoms, including bradyopsia (...
# 20  The proband's symptoms of bruising susceptibil...
# 21  The patient's presentation with incomplete rig...
# 22  The proband's symptoms, including limb hyperto...
# 23  The proband's symptoms align with Noonan syndr...
# 24  The proband's symptoms of reduced bone mineral...
# 25  The proband's symptoms align with Townes-Brock...
# 26  The proband's presentation is consistent with ...
# 27  The clinical presentation of the proband is hi...
# 28  The proband's symptoms are highly suggestive o...
# 29  The clinical presentation of the proband is co...
# 30  The proband's presentation is highly suggestiv...
# 31  The proband's symptoms, including joint hyperm...
# 32  The proband's symptoms, including intellectual...
# 33  The proband's symptoms align with Noonan Syndr...
# 34  The patient's symptoms are consistent with Dis...
# 35  The patient's symptoms, including arterial dis...
# 36  The proband's symptoms align with Koolen-de Vr...
# 37  The combination of severe intellectual disabil...
# 38  The infant's presentation is suggestive of Zel...
# 39  The patient's symptoms are consistent with Den...
# 40  The proband's features, including high and pro...
# 41  The clinical presentation of global developmen...
# 42  The clinical presentation of the proband, incl...
# 43  The proband's symptoms are consistent with Eme...
# 44  The proband's presentation is consistent with ...
# 45  The proband presents with autism but does not ...
# 46  The clinical presentation of the proband is su...
# 47  The patient's symptoms, including autistic beh...
# 48  The proband's symptoms are consistent with Cor...
# 49  The patient's symptoms, including ataxia, athe...

# %%
import chromadb

chroma_client = chromadb.PersistentClient(
                                    path=str('/Users/timhulshof/Documents/test_chatimd_latest/chatimd_interface/backend/chatimd_backend/databases/hpo_synonym_db')
                                )

collection = chroma_client.get_collection(name="hpo_synonym")

new_client = chromadb.PersistentClient(
                                    path=str(base_path / 'synthetic_patients')
                                )
new_client = chromadb.PersistentClient(
                                    path=str('/Users/timhulshof/Documents/test_chatimd_latest/chatimd_interface/backend/chatimd_backend/databases/synthetic_patients')
                                )

profiles = new_client.get_collection(name="synthetic_disease_profiles_v1")

# %%
import pickle

relevant_hpos = pickle.load(open(base_path / 'relevant_hpo_terms.pkl', 'rb'))

# %%
from utils.hpo_ontology import load_ontology

# Load the HPO ontology
graph, ic_dict = load_ontology(annotations='OMIM')

# %%
from oaklib import get_adapter

adapter = get_adapter(f"simpleobo:{base_path}/mondo.obo")

# %%
with open(base_path / "depth_cache.pkl", "rb") as f:
    depth_cache = pickle.load(f)

# %%
import utils.score_diagnosis 
import importlib

# make changes to example.py file
importlib.reload(utils.score_diagnosis)

from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate

results_path = Path().resolve() / 'results'

# Initialize dictionary to store times
execution_times = {}

# TOM
_, execution_times["TOM"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    depth_cache=depth_cache,
    # index=index,
    # orpha=False,
    collection=collection,
    weighted_score_active=True,
    # id_to_disease=id_to_disease,
    log_file_path=results_path / "evaluation_log_TOM_filtered_2.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_filtered_2.npz"
)
# Out:
#   0%|          | 0/4419 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_filtered_2.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_filtered_2.npz
# Time taken: 26166.23 seconds

# %%
import utils.score_diagnosis 
import importlib

# make changes to example.py file
importlib.reload(utils.score_diagnosis)
import utils.overlap_method
# make changes to example.py file
importlib.reload(utils.overlap_method)


from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate

results_path = Path().resolve() / 'results'

# TOM
_, execution_times["TOM_SA"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    depth_cache=depth_cache,
    # index=index,
    collection=collection,
    semantic_similarity=True,
    weighted_score_active=True,
    # id_to_disease=id_to_disease,
    log_file_path=results_path / "evaluation_log_TOM_SA_filtered_2.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_SA_filtered_2.npz"
)
# Out:
#   0%|          | 0/4419 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_SA_filtered_2.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_SA_filtered_2.npz
# Time taken: 29924.86 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[28], line 16
#      13 results_path = Path().resolve() / 'results'
#      15 # TOM
# ---> 16 _, execution_times["TOM_SA"] = timed_evaluate(
#      17     evaluate_predictions_and_save_logs,
#      18     relevant_hpos=relevant_hpos,
#      19     prompts_df=prompts_df,
#      20     adapter=adapter,
#      21     graph=graph,
#      22     ic_dict=ic_dict,
#      23     depth_cache=depth_cache,
#      24     # index=index,
#      25     collection=collection,
#      26     semantic_similarity=True,
#      27     weighted_score_active=True,
#      28     # id_to_disease=id_to_disease,
#      29     log_file_path=results_path / "evaluation_log_TOM_SA_filtered_2.txt",
#      30     output_ranks_path=results_path / "evaluation_ranks_TOM_SA_filtered_2.npz"
#      31 )
#
# NameError: name 'execution_times' is not defined

# %%
#!/usr/bin/env python3
# -*- coding: utf-8 -*-

import re, ast
from pathlib import Path
import pandas as pd

# ------------------------------------------------------------------
# 0.  FILE LOCATIONS  ------------------------------------------------
# results_path = Path(".")          #  <- adjust as needed
# base_path    = Path(".")          #  <- adjust as needed
results_path = Path().resolve() / 'results'
base_path    = Path().resolve() / 'files'

RAW_TXT = results_path / "evaluation_log_case_description_SA.txt"
HPO_OBO = base_path   / "hp.obo"

# ------------------------------------------------------------------
# 1.  REGEX PATTERNS  ------------------------------------------------
re_file    = re.compile(r'^File:\s*(.*)')
re_correct = re.compile(r'^Correct diagnosis:\s*(.*)')
# re_omim = re.compile(r'^ID\s+(\S+)') 
re_omim = re.compile(r'^ID.*?(\S+)$') 

metric_patterns = {
    "number_hpo_terms"                  : re.compile(r'^Number HPO terms\s+([\d.]+)'),
    "new_metric"                        : re.compile(r'^New Metric\s+([\d.]+)'),
    "number_matched_hpo_terms"          : re.compile(r'^Number matched HPO terms\s+([\d.]+)'),
    "fraction_overlap_search_hpo_terms" : re.compile(r'^Fraction overlapping search HPO terms\s+([\d.]+)'),
    "fraction_matched_disease_hpo_terms": re.compile(r'^Fraction matched disease HPO terms\s+([\d.]+)'),
    "weighted_score"                    : re.compile(r'^Weighted score\s+([\d.]+)'),
    "similarity"                        : re.compile(r'^Similarity\s+([\d.]+)'),
    "score"                             : re.compile(r'^Score\s+([\d.]+)'),
    "probability"                       : re.compile(r'^Probability\s+([\d.]+)'),
    "fdr"                               : re.compile(r'^FDR\s+([\d.]+)')
}

# block delimiter: any one of these starts the NEXT disease / ends current
re_block_end = re.compile(
    r'^(Error processing disease:|Name: OMIM:|Exact match|No match)'
)

# ------------------------------------------------------------------
# 2.  LOAD hp.obo  (ID → name)  -------------------------------------
def load_hpo_dict(obo_path: Path) -> dict:
    hpo_name, current = {}, None
    with obo_path.open(encoding="utf-8") as fh:
        for line in fh:
            if line.startswith("id: HP:"):
                current = line.split()[1].strip()
            elif line.startswith("name:") and current:
                hpo_name[current] = line[5:].strip()
                current = None
    return hpo_name

hpo_dict = load_hpo_dict(HPO_OBO)
print(f"Loaded {len(hpo_dict):,} HPO terms")

# robust “IDs → names”
def ids_to_names(raw):
    if raw in (None, '', []):
        ids = []
    elif isinstance(raw, (list, set, tuple)):
        ids = list(raw)
    elif isinstance(raw, str):
        try:
            maybe = ast.literal_eval(raw)
            if isinstance(maybe, (list, set, tuple)):
                ids = list(maybe)
            else:
                ids = [str(maybe)]
        except (ValueError, SyntaxError):
            ids = [x.strip() for x in raw.split(",") if x.strip()]
    else:
        ids = []
    return [hpo_dict.get(x, x) for x in ids]

# split simple comma-separated string into list of IDs
split_ids = lambda s: [x.strip() for x in s.split(",") if x.strip()]

# ------------------------------------------------------------------
# 3.  PARSE LOG FILE  -----------------------------------------------
rows, disease, current_file, correct_dx = [], {}, None, None

def flush():
    if not disease:
        return
    disease["file_name"]         = current_file
    disease["correct_diagnosis"] = correct_dx
    for k in metric_patterns:                     # ensure all metric cols exist
        disease.setdefault(k, None)
    for k in ("patient_hpo_ids","overlap_hpo_ids","disease_hpo_ids"):
        disease.setdefault(k, [])
    rows.append(disease.copy())
    disease.clear()

# def collect_until_close(initial, close_char, it):
#     buff = initial
#     for nxt in it:                # safe; stops at EOF
#         buff += " " + nxt.rstrip()
#         if close_char in buff:
#             break
#     return buff.split(close_char)[0]

def collect_until_close(initial_fragment, close_char, it):
    """
    Return the substring inside the list delimiters.
    *initial_fragment* is the text after the opening '[' or '{'.
    If the close_char is already present, we never advance the iterator.
    """
    buff = initial_fragment
    if close_char not in buff:                 # only read more if needed
        for nxt in it:                         # stops automatically at EOF
            buff += " " + nxt.rstrip()
            if close_char in buff:
                break
    return buff.split(close_char)[0]

with RAW_TXT.open(encoding="utf-8") as fh:
    for raw in fh:
        line = raw.rstrip()
        if not line:
            continue

        # new FILE block
        m = re_file.match(line)
        if m:
            flush()
            current_file = m.group(1).strip()
            correct_dx   = None
            continue

        # correct diagnosis
        m = re_correct.match(line)
        if m:
            correct_dx = m.group(1).strip()
            continue

        # explicit end-of-disease markers
        if re_block_end.match(line):
            flush()
            continue

        # first free-text line → disease_name
        if "disease_name" not in disease:
            disease["disease_name"] = line.strip()
            continue

        # e) OMIM ID  ------------------------------------------------------
        m = re.search(r'OMIM:\d+', line)          # find OMIM:<digits> anywhere
        if m:
            disease["omim_id"] = m.group()        # e.g. "OMIM:107480"
            continue

        # numeric metrics
        for key, rx in metric_patterns.items():
            m = rx.match(line)
            if m:
                val = m.group(1)
                disease[key] = int(val) if val.isdigit() else float(val)
                break
        else:   # no metric matched → maybe HPO lines
            if line.startswith("Patient HPOs"):
                first = line.split("{", 1)[1] if "{" in line else line.split("[",1)[1]
                full  = collect_until_close(first, "}" if "{" in line else "]", fh)
                disease["patient_hpo_ids"] = split_ids(full)
                continue
            if line.startswith("Overlap HPOs"):
                first = line.split("{", 1)[1]
                full  = collect_until_close(first, "}", fh)
                disease["overlap_hpo_ids"] = split_ids(full)
                continue
            if line.startswith("Disease HPOs"):
                first = line.split("{", 1)[1] if "{" in line else line.split("[",1)[1]
                full  = collect_until_close(first, "}" if "{" in line else "]", fh)
                disease["disease_hpo_ids"] = split_ids(full)
                continue

# flush last disease at EOF
flush()

# ------------------------------------------------------------------
# 4.  BUILD DATAFRAME & TRANSLATE NAMES  ----------------------------
df = pd.DataFrame(rows)

for col in ("patient_hpo_ids","overlap_hpo_ids","disease_hpo_ids"):
    name_col = col.replace("_ids","_names")
    df[name_col] = df[col].apply(ids_to_names)

front = ["file_name","correct_diagnosis","disease_name","omim_id","new_metric"]
df = df[front + [c for c in df.columns if c not in front]]

print(df.head(8))
# df.to_pickle(".pkl")
df.to_csv   ("all_predictions_with_hpo_prompts_case_descriptions.csv", index=False)
print("\n✓  Saved tidy dataframe with full HPO IDs and names")
# Out:
# Loaded 19,434 HPO terms
#   file_name      correct_diagnosis  \
# 0         1  DRAVET SYNDROME; DRVT
# 1         1  DRAVET SYNDROME; DRVT
# 2         1  DRAVET SYNDROME; DRVT
# 3         2  DRAVET SYNDROME; DRVT
# 4         2  DRAVET SYNDROME; DRVT
# 5         2  DRAVET SYNDROME; DRVT
# 6         2  DRAVET SYNDROME; DRVT
# 7         2  DRAVET SYNDROME; DRVT
#
#                                         disease_name      omim_id  new_metric  \
# 0          Mental retardation, autosomal dominant 42  OMIM:616973    0.456696
# 1  Multiple congenital anomalies-hypotonia-seizur...  OMIM:300868    0.445298
# 2  Epileptic encephalopathy, early infantile, 6 (...  OMIM:607208    0.443617
# 3     Developmental and epileptic encephalopathy 112  OMIM:620537    0.454924
# 4          Mental retardation, autosomal dominant 42  OMIM:616973    0.405977
# 5      Developmental and epileptic encephalopathy 91  OMIM:617711    0.402312
# 6       Developmental delay with or without epilepsy  OMIM:620540    0.392378
# 7      Epileptic encephalopathy, early infantile, 39  OMIM:612949    0.390815
#
#    number_hpo_terms  number_matched_hpo_terms  \
# 0              82.0                       8.0
# 1             202.0                       8.0
# 2              25.0                       5.0
# 3              32.0                       6.0
# 4              82.0                       8.0
# 5              37.0                       5.0
# 6              32.0                       5.0
# 7              46.0                       5.0
#
#    fraction_overlap_search_hpo_terms  fraction_matched_disease_hpo_terms  \
# 0                           0.097561                            0.444444
# 1                           0.039604                            0.444444
# 2                           0.200000                            0.277778
# 3                           0.187500                            0.285714
# 4                           0.097561                            0.380952
# 5                           0.135135                            0.238095
# 6                           0.156250                            0.238095
# 7                           0.108696                            0.238095
#
#    weighted_score  similarity     score  probability       fdr  \
# 0       34.257805    0.022053  0.003597     0.000000  0.000000
# 1       34.849413    0.001536  0.003697     0.000000  0.000000
# 2       23.800368    0.229624  0.009470     0.000019  0.034049
# 3       20.520397    0.236894  0.001986     0.000001  0.003247
# 4       28.405950    0.040425  0.001803     0.000000  0.000000
# 5       15.438393    0.215534  0.001382     0.000002  0.006749
# 6       16.432623    0.202496  0.001928     0.000005  0.014609
# 7       16.431285    0.200445  0.001452     0.000001  0.002146
#
#                                      patient_hpo_ids  \
# 0  [HP:0002372, HP:0002069, HP:0040168, HP:000735...
# 1  [HP:0002372, HP:0002069, HP:0040168, HP:000735...
# 2  [HP:0002372, HP:0002069, HP:0040168, HP:000735...
# 3  [HP:0001290, HP:0002133, HP:0002373, HP:000733...
# 4  [HP:0001290, HP:0002133, HP:0002373, HP:000733...
# 5  [HP:0001290, HP:0002133, HP:0002373, HP:000733...
# 6  [HP:0001290, HP:0002133, HP:0002373, HP:000733...
# 7  [HP:0001290, HP:0002133, HP:0002373, HP:000733...
#
#                                      overlap_hpo_ids  \
# 0  [HP:0002069, HP:0007359, HP:0002373, HP:000681...
# 1  [HP:0002069, HP:0002123, HP:0002373, HP:000133...
# 2  [HP:0002069, HP:0002123, HP:0006813, HP:000238...
# 3  [HP:0200134, HP:0002069, HP:0007359, HP:000213...
# 4  [HP:0002069, HP:0007359, HP:0002133, HP:000237...
# 5  [HP:0200134, HP:0002069, HP:0002133, HP:000126...
# 6  [HP:0002069, HP:0007359, HP:0002373, HP:000125...
# 7  [HP:0200134, HP:0002133, HP:0002373, HP:000126...
#
#                                      disease_hpo_ids  \
# 0  [HP:0032792, HP:0000577, HP:0011210, HP:000001...
# 1  [HP:0000365, HP:0001371, HP:0000396, HP:000169...
# 2  [HP:0011169, HP:0002133, HP:0001251, HP:000212...
# 3  [HP:0032712, HP:0001249, HP:0002133, HP:000125...
# 4  [HP:0032792, HP:0000577, HP:0011210, HP:000001...
# 5  [HP:0032792, HP:0004322, HP:0001609, HP:000231...
# 6  [HP:0001249, HP:0001251, HP:0002373, HP:000125...
# 7  [HP:0005469, HP:0032792, HP:0000300, HP:000213...
#
#                                    patient_hpo_names  \
# 0  [Normal interictal EEG, Bilateral tonic-clonic...
# 1  [Normal interictal EEG, Bilateral tonic-clonic...
# 2  [Normal interictal EEG, Bilateral tonic-clonic...
# 3  [Generalized hypotonia, Status epilepticus, Fe...
# 4  [Generalized hypotonia, Status epilepticus, Fe...
# 5  [Generalized hypotonia, Status epilepticus, Fe...
# 6  [Generalized hypotonia, Status epilepticus, Fe...
# 7  [Generalized hypotonia, Status epilepticus, Fe...
#
#                                    overlap_hpo_names  \
# 0  [Bilateral tonic-clonic seizure, Focal-onset s...
# 1  [Bilateral tonic-clonic seizure, Generalized m...
# 2  [Bilateral tonic-clonic seizure, Generalized m...
# 3  [Epileptic encephalopathy, Bilateral tonic-clo...
# 4  [Bilateral tonic-clonic seizure, Focal-onset s...
# 5  [Epileptic encephalopathy, Bilateral tonic-clo...
# 6  [Bilateral tonic-clonic seizure, Focal-onset s...
# 7  [Epileptic encephalopathy, Status epilepticus,...
#
#                                    disease_hpo_names
# 0  [Tonic seizure, Exotropia, EEG with occipital ...
# 1  [Hearing impairment, Flexion contracture, Over...
# 2  [Generalized clonic seizure, Status epilepticu...
# 3  [Focal impaired awareness motor seizure, Intel...
# 4  [Tonic seizure, Exotropia, EEG with occipital ...
# 5  [Tonic seizure, Short stature, Hoarse voice, U...
# 6  [Intellectual disability, Ataxia, Febrile seiz...
# 7  [Flat occiput, Tonic seizure, Oval face, Statu...
#
# ✓  Saved tidy dataframe with full HPO IDs and names

# %%
#!/usr/bin/env python3
"""
Jupyter‑ready helper to **parse the SA evaluation log** and attach the
original case descriptions from *LiteratureCases_12_5_25.csv*.

Drop the whole cell into a notebook, adjust the three paths below if
needed, run, and you’ll get a tidy `pandas.DataFrame` plus a CSV on
disk.
"""

# ---------------------------------------------------------------------
# 0️⃣  CONFIG — adjust paths if your folders differ
# ---------------------------------------------------------------------
from pathlib import Path
import re, ast, pandas as pd

LOG_PATH   = Path("results/evaluation_log_case_description_SA.txt")
CASES_CSV  = Path("files/LiteratureCases_12_5_25.csv")
OBO_PATH   = Path("files/hp.obo")          # optional – for name mapping
OUT_FILE   = "all_predictions_with_hpo_prompts_case_descriptions.csv"

# ---------------------------------------------------------------------
# 1️⃣  HPO ID → name (only if hp.obo is available)
# ---------------------------------------------------------------------
def load_hpo_names(obo_path: Path) -> dict:
    """Return {"HP:0000001": "All" , ...} (skips obsolete terms)."""
    if not obo_path.exists():
        return {}
    names, current = {}, None
    with obo_path.open(encoding="utf-8") as fh:
        for line in fh:
            if line.startswith("id: HP:"):
                current = line.split()[1]
            elif line.startswith("name:") and current:
                names[current] = line.split("name:",1)[1].strip()
                current = None
    return names

HPO_NAME = load_hpo_names(OBO_PATH)
ids2name = lambda x: HPO_NAME.get(x, x)

# ---------------------------------------------------------------------
# 2️⃣  REGEX TEMPLATES
# ---------------------------------------------------------------------
RE_FILE     = re.compile(r"^File:\s*(\d+)")
RE_CORRECT  = re.compile(r"^Correct diagnosis:\s*(.*)")
RE_EXACT    = re.compile(r"^Exact match Rank:\s*(\d+)")
RE_DEEPEST  = re.compile(r"^Deep(est| ancestor) match Rank:\s*(\d+)")

METRIC_RX   = {
    "number_hpo_terms"                  : re.compile(r"^Number HPO terms\s+([\d.]+)"),
    "number_matched_hpo_terms"          : re.compile(r"^Number matched HPO terms\s+([\d.]+)"),
    "fraction_overlap_search_hpo_terms" : re.compile(r"^Fraction overlapping search HPO terms\s+([\d.]+)"),
    "fraction_matched_disease_hpo_terms": re.compile(r"^Fraction matched disease HPO terms\s+([\d.]+)"),
    "weighted_score"                    : re.compile(r"^Weighted score\s+([\d.]+)"),
    "similarity"                        : re.compile(r"^Similarity\s+([\d.]+)"),
    "score"                             : re.compile(r"^Score\s+([\d.]+)"),
    "probability"                       : re.compile(r"^Probability\s+([\d.]+)"),
    "fdr"                               : re.compile(r"^FDR\s+([\d.]+)")
}

END_BLOCK  = re.compile(r"^(Error processing disease:|Name: OMIM:|Exact match|Deepest ancestor match|No match|File:)\b")

# helpers for HPO set capture -------------------------------------------------
ID_SPLIT = lambda s: [x.strip() for x in s.split(',') if x.strip()]

def collect_until_close(first_fragment: str, close_char: str, iterator):
    buff = first_fragment
    if close_char not in buff:
        for nxt in iterator:
            buff += ' ' + nxt.rstrip()
            if close_char in buff:
                break
    return buff.split(close_char)[0]

# ---------------------------------------------------------------------
# 3️⃣  PARSE THE LOG
# ---------------------------------------------------------------------
rows, disease = [], {}
cur_file = cur_dx = None
with LOG_PATH.open(encoding='utf-8') as fh:
    for raw in fh:
        line = raw.rstrip()
        if not line:
            continue

        # New FILE delimiter --------------------------------------------------
        m = RE_FILE.match(line)
        if m:
            # flush any existing disease before starting a new file block
            if disease:
                rows.append(disease)
                disease = {}
            cur_file = int(m.group(1))
            cur_dx   = None
            continue

        # Correct diagnosis
        m = RE_CORRECT.match(line)
        if m:
            cur_dx = m.group(1).strip()
            continue

        # Explicit end‑of‑disease markers
        if END_BLOCK.match(line):
            if disease:
                rows.append(disease)
                disease = {}
            continue

        # First free‑text line = disease candidate name
        if "disease_name" not in disease:
            disease["disease_name"] = line
            continue

        # Ranks ---------------------------------------------------------------
        m = RE_EXACT.match(line)
        if m:
            disease["exact_match_rank"] = int(m.group(1))
            continue
        m = RE_DEEPEST.match(line)
        if m:
            disease["deepest_ancestor_rank"] = int(m.group(2))
            continue

        # OMIM ID anywhere in line
        m = re.search(r"OMIM:\d+", line)
        if m:
            disease["omim_id"] = m.group()
            continue

        # Numeric metrics -----------------------------------------------------
        for key, rx in METRIC_RX.items():
            mm = rx.match(line)
            if mm:
                val = mm.group(1)
                disease[key] = float(val) if "." in val else int(val)
                break
        else:  # HPO sets ------------------------------------------------------
            if line.startswith("Patient HPOs"):
                first = line.split("{",1)[1]
                ids   = collect_until_close(first, "}", fh)
                disease["patient_hpo_ids"] = ID_SPLIT(ids)
            elif line.startswith("Overlap HPOs"):
                first = line.split("{",1)[1]
                ids   = collect_until_close(first, "}", fh)
                disease["overlap_hpo_ids"] = ID_SPLIT(ids)
            elif line.startswith("Disease HPOs"):
                first = line.split("{",1)[1]
                ids   = collect_until_close(first, "}", fh)
                disease["disease_hpo_ids"] = ID_SPLIT(ids)

    # flush last block at EOF
    if disease:
        rows.append(disease)

# ---------------------------------------------------------------------
# 4️⃣  BUILD DATAFRAME AND MERGE CASE DESCRIPTIONS
# ---------------------------------------------------------------------
log_df = pd.DataFrame(rows)
log_df["id"] = log_df["file_name"] = log_df.pop("file_name") if "file_name" in log_df else log_df.index + 1
log_df["correct_diagnosis"] = cur_dx

# add name‑translated HPO columns (optional)
for col in ("patient_hpo_ids","overlap_hpo_ids","disease_hpo_ids"):
    if col in log_df:
        log_df[col.replace("_ids","_names")] = log_df[col].apply(lambda lst: [ids2name(x) for x in lst])

# Case descriptions -----------------------------------------------------------
case_df = pd.read_csv(CASES_CSV, usecols=["id","caseDescription"])
full_df = log_df.merge(case_df, on="id", how="left")

# Convenience boolean flags
full_df["exact_match_found"]     = full_df["exact_match_rank"].notna()
full_df["deepest_ancestor_found"] = full_df["deepest_ancestor_rank"].notna()

# Save & preview --------------------------------------------------------------
full_df.to_csv(OUT_FILE, index=False)
print(f"✓  Saved {len(full_df):,} rows → {OUT_FILE}")
full_df.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 167
#     165 for col in ("patient_hpo_ids","overlap_hpo_ids","disease_hpo_ids"):
#     166     if col in log_df:
# --> 167         log_df[col.replace("_ids","_names")] = log_df[col].apply(lambda lst: [ids2name(x) for x in lst])
#     169 # Case descriptions -----------------------------------------------------------
#     170 case_df = pd.read_csv(CASES_CSV, usecols=["id","caseDescription"])
#
# File ~/Documents/analysis_chatimd/venv/lib/python3.11/site-packages/pandas/core/series.py:4924, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4789 def apply(
#    4790     self,
#    4791     func: AggFuncType,
#    (...)
#    4796     **kwargs,
#    4797 ) -> DataFrame | Series:
#    4798     """
#    4799     Invoke function on values of Series.
#    4800
#    (...)
#    4915     dtype: float64
#    4916     """
#    4917     return SeriesApply(
#    4918         self,
#    4919         func,
#    4920         convert_dtype=convert_dtype,
#    4921         by_row=by_row,
#    4922         args=args,
#    4923         kwargs=kwargs,
# -> 4924     ).apply()
#
# File ~/Documents/analysis_chatimd/venv/lib/python3.11/site-packages/pandas/core/apply.py:1427, in SeriesApply.apply(self)
#    1424     return self.apply_compat()
#    1426 # self.func is Callable
# -> 1427 return self.apply_standard()
#
# File ~/Documents/analysis_chatimd/venv/lib/python3.11/site-packages/pandas/core/apply.py:1507, in SeriesApply.apply_standard(self)
#    1501 # row-wise access
#    1502 # apply doesn't have a `na_action` keyword and for backward compat reasons
#    1503 # we need to give `na_action="ignore"` for categorical data.
#    1504 # TODO: remove the `na_action="ignore"` when that default has been changed in
#    1505 #  Categorical (GH51645).
#    1506 action = "ignore" if isinstance(obj.dtype, CategoricalDtype) else None
# -> 1507 mapped = obj._map_values(
#    1508     mapper=curried, na_action=action, convert=self.convert_dtype
#    1509 )
#    1511 if len(mapped) and isinstance(mapped[0], ABCSeries):
#    1512     # GH#43986 Need to do list(mapped) in order to get treated as nested
#    1513     #  See also GH#25959 regarding EA support
#    1514     return obj._constructor_expanddim(list(mapped), index=obj.index)
#
# File ~/Documents/analysis_chatimd/venv/lib/python3.11/site-packages/pandas/core/base.py:921, in IndexOpsMixin._map_values(self, mapper, na_action, convert)
#     918 if isinstance(arr, ExtensionArray):
#     919     return arr.map(mapper, na_action=na_action)
# --> 921 return algorithms.map_array(arr, mapper, na_action=na_action, convert=convert)
#
# File ~/Documents/analysis_chatimd/venv/lib/python3.11/site-packages/pandas/core/algorithms.py:1743, in map_array(arr, mapper, na_action, convert)
#    1741 values = arr.astype(object, copy=False)
#    1742 if na_action is None:
# -> 1743     return lib.map_infer(values, mapper, convert=convert)
#    1744 else:
#    1745     return lib.map_infer_mask(
#    1746         values, mapper, mask=isna(values).view(np.uint8), convert=convert
#    1747     )
#
# File lib.pyx:2972, in pandas._libs.lib.map_infer()
#
# Cell In[1], line 167, in <lambda>(lst)
#     165 for col in ("patient_hpo_ids","overlap_hpo_ids","disease_hpo_ids"):
#     166     if col in log_df:
# --> 167         log_df[col.replace("_ids","_names")] = log_df[col].apply(lambda lst: [ids2name(x) for x in lst])
#     169 # Case descriptions -----------------------------------------------------------
#     170 case_df = pd.read_csv(CASES_CSV, usecols=["id","caseDescription"])
#
# TypeError: 'float' object is not iterable

# %%
import utils.score_diagnosis 
import importlib
import utils.overlap_method
# make changes to example.py file
importlib.reload(utils.score_diagnosis)
importlib.reload(utils.overlap_method)

from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate

results_path = Path().resolve() / 'results'

# TOM
_, execution_times["TOM_SA_HNSW_WHOLE"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    depth_cache=depth_cache,
    index=profiles,
    collection=collection,
    semantic_similarity=True,
    hnsw=True,
    k=1000,
    id_to_disease=None,
    weighted_score_active=True,
    log_file_path=results_path / "evaluation_log_TOM_SA_HNSW_smaller_k=1000.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_SA_HNSW_smaller_k=1000.npz"
)
# Out:
#   0%|          | 0/4419 [00:00<?, ?it/s]
# INFO:backoff:Backing off send_request(...) for 1.0s (requests.exceptions.ReadTimeout: HTTPSConnectionPool(host='us.i.posthog.com', port=443): Read timed out. (read timeout=15))
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_SA_HNSW_smaller_k=1000.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_SA_HNSW_smaller_k=1000.npz
# Time taken: 17915.90 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[31], line 13
#      10 results_path = Path().resolve() / 'results'
#      12 # TOM
# ---> 13 _, execution_times["TOM_SA_HNSW_WHOLE"] = timed_evaluate(
#      14     evaluate_predictions_and_save_logs,
#      15     relevant_hpos=relevant_hpos,
#      16     prompts_df=prompts_df,
#      17     adapter=adapter,
#      18     graph=graph,
#      19     ic_dict=ic_dict,
#      20     depth_cache=depth_cache,
#      21     index=profiles,
#      22     collection=collection,
#      23     semantic_similarity=True,
#      24     hnsw=True,
#      25     k=1000,
#      26     id_to_disease=None,
#      27     weighted_score_active=True,
#      28     log_file_path=results_path / "evaluation_log_TOM_SA_HNSW_smaller_k=1000.txt",
#      29     output_ranks_path=results_path / "evaluation_ranks_TOM_SA_HNSW_smaller_k=1000.npz"
#      30 )
#
# NameError: name 'execution_times' is not defined

# %%
from pathlib import Path
import pronto   # pip install pronto

# 1) load the ontology (only once)
hpo = pronto.Ontology(base_path / "hp.obo")   # path to your hp.obo

# 2) function to translate
def hpo_id_to_name(hpo_id: str) -> str:
    """Return the primary term name (or the code itself if not found)."""
    try:
        return hpo[hpo_id].name
    except KeyError:
        return hpo_id

# 3) translate your list
codes = [
    "HP:0000822", "HP:0001945", "HP:0001903", "HP:0001974", "HP:0007663",
    "HP:0001824", "HP:0002027", "HP:0003259", "HP:0002315", "HP:0025406",
    "HP:0000790", "HP:0005978", "HP:0002716", "HP:0002013", "HP:0002014"
]

for code in codes:
    print(f"{code}  →  {hpo_id_to_name(code)}")
# Out:
# /var/folders/wm/nmccdgwx5v33gkxvs2l3pgvc0000gn/T/ipykernel_82180/567326789.py:5: UnicodeWarning: unsound encoding, assuming ISO-8859-1 (73% confidence)
#   hpo = pronto.Ontology(base_path / "hp.obo")   # path to your hp.obo
# HP:0000822  →  Hypertension
# HP:0001945  →  Fever
# HP:0001903  →  Anemia
# HP:0001974  →  Leukocytosis
# HP:0007663  →  Reduced visual acuity
# HP:0001824  →  Weight loss
# HP:0002027  →  Abdominal pain
# HP:0003259  →  Elevated circulating creatinine concentration
# HP:0002315  →  Headache
# HP:0025406  →  Asthenia
# HP:0000790  →  Hematuria
# HP:0005978  →  Type II diabetes mellitus
# HP:0002716  →  Lymphadenopathy
# HP:0002013  →  Vomiting
# HP:0002014  →  Diarrhea

# %%
import utils.score_diagnosis 
import importlib

# make changes to example.py file
importlib.reload(utils.score_diagnosis)

from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate

results_path = Path().resolve() / 'results'

# TOM
_, execution_times["TOM_SA_HNSW_WHOLE"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    depth_cache=depth_cache,
    index=index,
    collection=collection,
    semantic_similarity=True,
    hnsw=True,
    k=int(len(final_profile_df) / 2),
    id_to_disease=id_to_disease,
    weighted_score_active=False,
    log_file_path=results_path / "evaluation_log_TOM_SA_HNSW_WHOLE_HALF.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_SA_HNSW_WHOLE_HALF.npz"
)
# Out:
#   0%|          | 0/5212 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_SA_HNSW_WHOLE_HALF.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_SA_HNSW_WHOLE_HALF.npz
# Time taken: 35315.28 seconds

# %%
import utils.score_diagnosis 
import importlib

# make changes to example.py file
importlib.reload(utils.score_diagnosis)

from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate
import matplotlib.pyplot as plt

results_path = Path().resolve() / 'results'

# Initialize dictionary to store times
execution_times = {}

# TOM
_, execution_times["TOM"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    index=index,
    collection=collection,
    id_to_disease=id_to_disease,
    log_file_path=results_path / "evaluation_log_TOM.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM.npz"
)

# TOM_SA
_, execution_times["TOM_SA"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    index=index,
    id_to_disease=id_to_disease,
    collection=collection,
    semantic_similarity=True,
    log_file_path=results_path / "evaluation_log_TOM_SA.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_SA.npz"
)

# Print summary of execution times
print("\nSummary of Execution Times:")
for method, elapsed_time in execution_times.items():
    print(f"{method}: {elapsed_time:.2f} seconds")

# Extract method names and their corresponding execution times
methods = list(execution_times.keys())
times = list(execution_times.values())

# Create the bar chart
plt.figure(figsize=(8, 6))
bars = plt.bar(methods, times, color='skyblue')

# Add labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f} s', ha='center', va='bottom')

# Add title and labels
plt.title("Execution Times for Different Methods")
plt.xlabel("Methods")
plt.ylabel("Execution Time (seconds)")

# Show the chart
plt.tight_layout()
plt.show()
# Out:
#   0%|          | 0/5145 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM.npz
# Time taken: 31057.76 seconds
#   0%|          | 0/5145 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_SA.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_SA.npz
# Time taken: 33124.02 seconds
#   0%|          | 0/5145 [00:00<?, ?it/s]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[16], line 47
#      31 _, execution_times["TOM_SA"] = timed_evaluate(
#      32     evaluate_predictions_and_save_logs,
#      33     relevant_hpos=relevant_hpos,
#    (...)
#      43     output_ranks_path=results_path / "evaluation_ranks_TOM_SA.npz"
#      44 )
#      46 # TOM_SA_HNSW
# ---> 47 _, execution_times["TOM_SA_HNSW"] = timed_evaluate(
#      48     evaluate_predictions_and_save_logs,
#      49     relevant_hpos=relevant_hpos,
#      50     prompts_df=prompts_df,
#      51     adapter=adapter,
#      52     graph=graph,
#      53     ic_dict=ic_dict,
#      54     index=index,
#      55     id_to_disease=id_to_disease,
#      56     collection=collection,
#      57     semantic_similarity=True,
#      58     hnsw=True,
#      59     log_file_path=results_path / "evaluation_log_TOM_SA_HNSW.txt",
#      60     output_ranks_path=results_path / "evaluation_ranks_TOM_SA_HNSW.npz"
#      61 )
#      63 # Print summary of execution times
#      64 print("\nSummary of Execution Times:")
#
# File ~/Documents/analysis_chatimd/utils/score_diagnosis.py:187, in timed_evaluate(evaluate_function, *args, **kwargs)
#       0 <Error retrieving source code with stack_data see ipython/ipython#13598>
#
# File ~/Documents/analysis_chatimd/utils/score_diagnosis.py:116, in evaluate_predictions_and_save_logs(relevant_hpos, prompts_df, adapter, graph, ic_dict, index, id_to_disease, collection, semantic_similarity, hnsw, log_file_path, output_ranks_path)
#     114         exact_match_deepest_ancestor_match_ranks.append(i+1)
#     115         deepest_ancestor_match = True
# --> 116     break
#     117 elif score == "Deepest ancestor match" and not deepest_ancestor_match:
#     118     log_file.write(f"{score} Rank: {i+1}\n")
#
# File ~/Documents/analysis_chatimd/utils/synthetic_dataset_utils.py:86, in retrieve_nearest_neighbours(hpo_terms, index, id_to_disease, collection, k)
#      83 new_embedding = np.array(new_embedding).astype('float32')
#      85 # Query the index for the 100 nearest neighbors
# ---> 86 labels, distances = index.knn_query(new_embedding, k=k)
#      88 # Retrieve the corresponding disease names
#      89 nearest_diseases = [id_to_disease[id] for id in labels[0]]
#
# RuntimeError: Input vector data wrong shape. Number of dimensions 0. Data must be a 1D or 2D array.

# %%
import pickle 

with open(results_path / 'saved_times.pkl', 'wb') as f:
    pickle.dump(execution_times, f)

# %%
import utils.score_diagnosis 
import importlib

# make changes to example.py file
importlib.reload(utils.score_diagnosis)

from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate

results_path = Path().resolve() / 'results'

execution_times = {}

# TOM_SA_HNSW
_, execution_times["TOM_SA_HNSW_higher_ef_m"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    index=index,
    id_to_disease=id_to_disease,
    collection=collection,
    semantic_similarity=True,
    diseases_to_consider=diseases_in_index,
    hnsw=True,
    log_file_path=results_path / "evaluation_log_TOM_SA_HNSW_higher_ef_m.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_SA_HNSW_higher_ef_m.npz"
)

# Print summary of execution times
print("\nSummary of Execution Times:")
for method, elapsed_time in execution_times.items():
    print(f"{method}: {elapsed_time:.2f} seconds")

# Extract method names and their corresponding execution times
methods = list(execution_times.keys())
times = list(execution_times.values())

# Create the bar chart
plt.figure(figsize=(8, 6))
bars = plt.bar(methods, times, color='skyblue')

# Add labels above each bar
for bar in bars:
    height = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2, height, f'{height:.2f} s', ha='center', va='bottom')

# Add title and labels
plt.title("Execution Times for Different Methods")
plt.xlabel("Methods")
plt.ylabel("Execution Time (seconds)")

# Show the chart
plt.tight_layout()
plt.show()
# 1hr 38min
# Out:
#   0%|          | 0/5145 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_SA_HNSW_higher_ef_m.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_SA_HNSW_higher_ef_m.npz
# Time taken: 6725.57 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[30], line 12
#       9 results_path = Path().resolve() / 'results'
#      11 # TOM_SA_HNSW
# ---> 12 _, execution_times["TOM_SA_HNSW_higher_ef_m"] = timed_evaluate(
#      13     evaluate_predictions_and_save_logs,
#      14     relevant_hpos=relevant_hpos,
#      15     prompts_df=prompts_df,
#      16     adapter=adapter,
#      17     graph=graph,
#      18     ic_dict=ic_dict,
#      19     index=index,
#      20     id_to_disease=id_to_disease,
#      21     collection=collection,
#      22     semantic_similarity=True,
#      23     diseases_to_consider=diseases_in_index,
#      24     hnsw=True,
#      25     log_file_path=results_path / "evaluation_log_TOM_SA_HNSW_higher_ef_m.txt",
#      26     output_ranks_path=results_path / "evaluation_ranks_TOM_SA_HNSW_higher_ef_m.npz"
#      27 )
#      29 # Print summary of execution times
#      30 print("\nSummary of Execution Times:")
#
# NameError: name 'execution_times' is not defined

# %%
# TOM_SA
execution_times = {}

_, execution_times["TOM_SA_index_diseases"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    index=index,
    id_to_disease=id_to_disease,
    collection=collection,
    semantic_similarity=True,
    diseases_to_consider=diseases_in_index,
    log_file_path=results_path / "evaluation_log_TOM_SA_index_diseases.txt", 
    output_ranks_path=results_path / "evaluation_ranks_TOM_SA_index_diseases.npz")
# Out:
#   0%|          | 0/5145 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_TOM_SA_index_diseases.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_TOM_SA_index_diseases.npz
# Time taken: 14928.63 seconds

# %%
from utils.hdc import load_hpo_terms, create_hpo_vector_lookup, load_phenotype_hpoa, build_disease_vectors, create_disease_name_mapping

# Load data
hpo_terms = load_hpo_terms(base_path / 'hp.obo')
hpo_vectors = create_hpo_vector_lookup(hpo_terms)
hpoa_df = load_phenotype_hpoa(base_path / 'phenotype.hpoa')
hpoa_df = hpoa_df[hpoa_df['database_id'].str.startswith('OMIM')]
disease_vectors = build_disease_vectors(hpoa_df, hpo_vectors)
disease_names = create_disease_name_mapping(hpoa_df)
# Out:
# Building disease vectors...

# %%
import utils.score_diagnosis 
import importlib

# make changes to example.py file
importlib.reload(utils.score_diagnosis)

from utils.score_diagnosis import evaluate_predictions_and_save_logs, timed_evaluate

results_path = Path().resolve() / 'results'

# TOM
_, execution_times["TOM_SA"] = timed_evaluate(
    evaluate_predictions_and_save_logs,
    relevant_hpos=relevant_hpos, 
    prompts_df=prompts_df, 
    adapter=adapter, 
    graph=graph, 
    ic_dict=ic_dict, 
    depth_cache=depth_cache,
    index=None,
    collection=collection,
    semantic_similarity=True,
    weighted_score_active=False,
    id_to_disease=None,
    hdc=True, 
    disease_vectors=disease_vectors,
    disease_names=disease_names,
    hpo_vectors=hpo_vectors,
    log_file_path=results_path / "evaluation_log_HDC.txt", 
    output_ranks_path=results_path / "evaluation_ranks_HDC.npz")
# Out:
#   0%|          | 0/5212 [00:00<?, ?it/s]
# Logs saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_log_HDC.txt
# Ranks saved to /Users/timhulshof/Documents/analysis_chatimd/results/evaluation_ranks_HDC.npz
# Time taken: 18121.96 seconds
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 12
#       9 results_path = Path().resolve() / 'results'
#      11 # TOM
# ---> 12 _, execution_times["TOM_SA"] = timed_evaluate(
#      13     evaluate_predictions_and_save_logs,
#      14     relevant_hpos=relevant_hpos,
#      15     prompts_df=prompts_df,
#      16     adapter=adapter,
#      17     graph=graph,
#      18     ic_dict=ic_dict,
#      19     depth_cache=depth_cache,
#      20     index=None,
#      21     collection=collection,
#      22     semantic_similarity=True,
#      23     weighted_score_active=False,
#      24     id_to_disease=None,
#      25     hdc=True,
#      26     disease_vectors=disease_vectors,
#      27     disease_names=disease_names,
#      28     hpo_vectors=hpo_vectors,
#      29     log_file_path=results_path / "evaluation_log_HDC.txt",
#      30     output_ranks_path=results_path / "evaluation_ranks_HDC.npz")
#
# NameError: name 'execution_times' is not defined
